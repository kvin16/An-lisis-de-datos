# %% [markdown]
#  # Programación para el Análisis de Datos
#  ### Tarea 1
#  ### Presentado por: Kevin Alejandro Cardenas Quintero
#  ### Grupo 39
#  ### Código: 203008069
#  ### Presentado a: Felipe Alexander Pipicano Guzman
#  ### Universidad Nacional Abierta y a Distancia - UNAD
#  ### 14 de Marzo 2024

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# ## Teoría
#
# Los gráficos científicos son herramientas fundamentales en la comunicación de resultados de investigación, ya que permiten visualizar datos de manera efectiva y comprensible. Estos gráficos se utilizan en una amplia variedad de disciplinas científicas. Estos son algunos de los gráficos científicos mas comunes y sus aplicaciones:
#
# 1. **Gráficos de dispersión:**
#
# Los gráficos de dispersión son utilizados para visualizar la relación entre dos variables continuas.
# Cada punto en el gráfico representa una observación y su posición está determinada por los valores de las dos variables.
# Estos gráficos son útiles para identificar patrones, tendencias y correlaciones entre las variables.
#
# 2. **Histogramas:**
#
# Los histogramas son utilizados para representar la distribución de una variable continua.
# El eje x representa los valores de la variable, mientras que el eje y representa la frecuencia de ocurrencia de cada valor.
# Los histogramas son útiles para identificar la forma de la distribución, incluyendo su sesgo, simetría y presencia de picos o modas.
#
# 3. **Gráficos de barras:**
#
# Los gráficos de barras son utilizados para comparar la magnitud de diferentes categorías o grupos.
# Cada barra representa una categoría y su altura indica la magnitud de la variable que se está comparando.
# Estos gráficos son útiles para visualizar diferencias entre categorías y para hacer comparaciones entre grupos.
#
# 4. **Gráficos de líneas:**
#
# Los gráficos de líneas son utilizados para representar cambios en una variable a lo largo del tiempo o en función de otra variable.
# Cada punto en el gráfico está conectado por una línea, lo que permite visualizar tendencias y patrones temporales.
#
# 5. **Diagramas de caja (Boxplots):**
#
# Los diagramas de caja son utilizados para representar la distribución de una variable y resumir sus estadísticos clave.
# Estos gráficos muestran la mediana, los cuartiles y los valores atípicos de una distribución, proporcionando una descripción visual de la dispersión de los datos.
#
# 6. **Diagramas de dispersión tridimensional:**
#
# Estos gráficos son una extensión de los gráficos de dispersión convencionales, pero representan la relación entre tres variables en lugar de dos.
# Son útiles para visualizar relaciones más complejas entre múltiples variables.
#
# 7. **Mapas de calor (Heatmaps):**
#
# Los mapas de calor son utilizados para visualizar la intensidad de una variable en una matriz bidimensional.
# Los valores de la variable se representan mediante colores, lo que permite identificar patrones espaciales o de densidad en los datos.

# %% [markdown]
# # Descripción del ejercicio:
#
# Desarrolle códigos para generar y visualizar los siguientes gráficos:
#
# ## Gráfico 1:
# Esta visualización debe cumplir con las siguientes condiciones:
#
# • Mostrar los puntos de dispersión del emparejamiento las siguientes listas:
# $x= [13,14,15,16,17,18]$ , $y= [16,24,45,57,75,102]$
#
# • Mostrar la función lineal $𝒇(𝒙) = 𝟏𝟕𝒙 − 𝟐𝟏𝟎. 𝟑𝟑𝟑𝟑$ en el dominio [13,18].
#
# • Mostrar la función exponencial $𝒈(𝒙) = 𝟎. 𝟏𝟒𝟓𝟐 𝒆(𝟎.𝟑𝟔𝟗𝒙)$ en el dominio [13,18].
#
# • Mostrar la función logarítmica $𝒉(𝒙) = 𝟐𝟓𝟗. 𝟒𝟗 𝒍𝒏(𝒙) − 𝟔𝟓𝟔. 𝟒𝟔 $en el dominio [13,18].
#
# • Los objetos mostrados deben tener colores diferentes.
#
# • La línea de la función logarítmica debe ser punteada.
#
# • En los ejes deben visualizarse los números.
#
# • Asigne un nombre (label) a cada objeto e imprima la legenda
# que los identifique en la gráfica.
#
# • Asigne nombres a los ejes de la gráfica.
#
# • Asigne un título a la gráfica.
#
# • Tenga en cuenta que los nombres que decida utilizar le serán de
# ayuda para presentar las conclusiones que usted obtenga del ejercicio.el ejercicio.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos
x = np.array([13, 14, 15, 16, 17, 18])
y = np.array([16, 24, 45, 57, 75, 102])

# Funciones
def f(x):
    return 17*x - 210.3334

def g(x):
    return 0.1452 * np.exp(0.369*x)

def h(x):
    return 259.49 * np.log(x) - 656.44

# Gráfico Disperción

plt.scatter(x, y, color='red', label='Datos')

#crear valores de x en el dominio
x = np.linspace(13, 18, 100)

# Gráfico lineal

plt.plot(x, f(x), color='blue', label='f(x) := 17x - 210.3334')
plt.plot(x, g(x), color='green', label='g(x) := 0.1452 * e^(0.369x)')
plt.plot(x, h(x), '--', color='orange', label='h(x) := 259.49 * ln(x) - 656.44')

# Etiquetas y título
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico de dispersión con funciones')

# Leyenda
plt.legend()

# Mostrar gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# ### Análisis de resultados.
#
# Los puntos rojos representan los datos de dispersión, que muestran la relación entre las variables x e y, a simple vista, los datos parecen seguir una tendencia ascendente a medida que aumenta el valor de x.
#
# El objetivo de trazar estas funciones junto con los datos es evaluar qué tan bien se ajustan las funciones a los datos reales. Si las funciones modelan correctamente los datos, las líneas pasarán cerca de los puntos de dispersión.
#
# La función lineal en color azul parece ajustarse razonablemente bien a los puntos de dispersión en la parte inferior izquierda del gráfico.
# Sin embargo, a medida que avanzamos hacia la parte superior derecha del gráfico, la discrepancia entre la función y los datos observados se hace más evidente.
#
# La función exponencial en color verde parece no ajustarse adecuadamente a los puntos de dispersión. Se observa una discrepancia significativa entre la función y los datos en toda la gama de valores.
#
# La función logarítmica en color naranja muestra un ajuste mixto a los datos observados. En la parte inferior izquierda del gráfico, la función logarítmica parece ajustarse razonablemente bien a los datos, pero a medida que nos movemos hacia la parte superior derecha, la discrepancia entre la función y los datos se hace más evidente.

# %% [markdown]
# ## Gráfico 2:
#
# Construya los códigos necesarios para:
#
# • Generar 4 listas aleatorias de 700 muestras (revise la documentación de numpy.random):
# 1. x1 con distribución normal de media 5 y desviación estándar 0.1.
# 2. y1 con distribución normal de media 7 y desviación estándar 0.1.
# 3. x2 con distribución uniforme entre el valor mínimo de x1 y el valor máximo de x1.
# 4. y2 con distribución uniforme entre el valor mínimo de y1 y el valor máximo de y1.
#
# • Graficar en un mismo plot nubes de dispersión de los pares de puntos que se forman con (x1, y1) y (x2, y2).
#
# • La nube de puntos (x2, y2) debe visualizarse sobre la nube de (x1, y1).
#
# • Anexe los títulos y legendas necesarios para poder citar y explicar realizar el análisis del gráfico obtenido y las conclusiones.

# %%
# Generación de datos
np.random.seed(0)  # Para reproducibilidad

# Generar x1 e y1 con distribución normal
x1 = np.random.normal(loc=5, scale=0.1, size=700)
y1 = np.random.normal(loc=7, scale=0.1, size=700)

# Generar x2 e y2 con distribución uniforme
x2 = np.random.uniform(low=min(x1), high=max(x1), size=700)
y2 = np.random.uniform(low=min(y1), high=max(y1), size=700)

# Gráfico de dispersión
plt.scatter(x1, y1, color='blue', label='Datos (x1, y1)', alpha=0.5)
plt.scatter(x2, y2, color='red', label='Datos (x2, y2)', alpha=0.7)

# Títulos y leyenda
plt.title('Nubes de dispersión de datos generados')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.legend()

# Mostrar gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# ### Análisis de resultados.
#
# Se trazan dos nubes de puntos en el gráfico, una en color azul para los datos (x1, y1) y otra en color rojo para los datos (x2, y2).
# Cada punto en el gráfico representa un par de coordenadas (x, y), donde x corresponde a los valores en el eje horizontal y y corresponde a los valores en el eje vertical.
#
# Los puntos se distribuyen aleatoriamente en el gráfico debido a la naturaleza aleatoria de los datos generados.
# No parece haber una relación evidente entre los conjuntos de datos (x1, y1) y (x2, y2), ya que se distribuyen de manera independiente y no muestran una tendencia clara.
#
# La nube de puntos azules (x1, y1) muestra una distribución más concentrada alrededor de un cierto rango de valores, lo que indica una menor dispersión en comparación con la nube de puntos rojos (x2, y2).
# La nube de puntos rojos (x2, y2) muestra una distribución más uniforme debido a la generación de datos con una distribución uniforme.

# %% [markdown]
# ## Gráficos 3:
#
# Genere las siguientes dos visualizaciones que se proponen a continuación:
#
# • Cargue en la variable df1 el conjunto de datos que se presentan en el archivo Excel, Anexo 1 - Base de Datos Excel.xlsx, que se encuentra en la carpeta de la Tarea 1 - Fundamentos de programación científica con Python.
#
# • En una misma gráfica presente 2 histogramas de las variables Tiempo motor ON y Tiempo en Movimiento, respectivamente. Deben ser lo suficientemente transparentes, para poder ver ambas al tiempo. (Revise la documentación de la función matplotlib.pyplot.hist).
#
# • En otra gráfica, genere el gráfico de dispersión que se obtiene de emparejar los valores de Tiempo motor ON y Tiempo en Movimiento.
#
# • Anexe los títulos y legendas necesarios en ambos gráficos para poder citar y explicar el análisis de los gráficos obtenidos y las conclusiones.

# %%
import pandas as pd

# Cargar los datos desde el archivo Excel
df1 = pd.read_excel('Anexo 1 - Base de Datos EXCEL.xlsx', sheet_name = "BASE DE DATOS",  header=3)

# Gráfico de histogramas
plt.figure(figsize=(10, 5))

# Histograma de Tiempo motor ON
plt.hist(df1['Tiempo motor ON (h)'], bins=30, alpha=0.5, color='blue', label='Tiempo motor ON', density=True)

# Histograma de Tiempo en Movimiento
plt.hist(df1['Tiempo en Movimiento (h)'], bins=30, alpha=0.5, color='green', label='Tiempo en Movimiento', density=True)

# Títulos y leyendas
plt.title('Histograma de Tiempo motor ON y Tiempo en Movimiento')
plt.xlabel('Tiempo')
plt.ylabel('Densidad de frecuencia')
plt.legend()

# Mostrar gráfico
plt.grid(True)
plt.show()

# Gráfico de dispersión
plt.figure(figsize=(8, 6))

# Dispersión de Tiempo motor ON vs Tiempo en Movimiento
plt.scatter(df1['Tiempo motor ON (h)'], df1['Tiempo en Movimiento (h)'], color='red', alpha=0.5)

# Títulos y leyendas
plt.title('Dispersión de Tiempo motor ON vs Tiempo en Movimiento')
plt.xlabel('Tiempo motor ON')
plt.ylabel('Tiempo en Movimiento')

# Mostrar gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# ### Análisis de resultados.
#
# **Histogramas de Tiempo motor ON y Tiempo en Movimiento:**
#
# -Se observa que la mayoría de los datos se concentran en ciertos rangos de tie, llegando al tiempo 3mpo, lo que sugiere que hay períodos en los que el motor está encendido y el vehículo está en movimiento durante lapsos específicos.
#
# -La distribución de tiempo en movimiento parece ser más dispersa que la distribución del tiempo del motor encendido.
#
# **Gráfico de dispersión de Tiempo motor ON vs Tiempo en Movimiento**
#
# El gráfico de dispersión muestra la relación entre las variables "Tiempo motor ON" y "Tiempo en Moviento. Seento".
#
# Se observa una tendencia general de incremento en el tiempo en movimiento a medida que aumenta el tiempo del motor encendido, lo que sugiere que hay una relación positiva entre estas dos variables. Sin embargo, también se observa cierta dispersión en los datos, lo que indica que hay otros factores que pueden influir en el tiempo en movimiento además del tiempo del motor encendido.

# %% [markdown]
# ## Conclusiones
#
# Las visualizaciones de datos son una herramienta fundamental en el análisis de datos, ya que proporcionan una forma intuitiva y efectiva de comprender la estructura y las relaciones presentes en los conjuntos de datos. Al representar los datos de manera gráfica, podemos identificar patrones, tendencias y dispersión que pueden no ser evidentes al observar simplemente los números.
#
# Estas visualizaciones no solo nos ayudan a comprender mejor los datos, sino que también pueden proporcionar información valiosa para la toma de decisiones. Al identificar áreas de interés o tendencias emergentes, podemos tomar medidas proactivas o realizar análisis adicionales para profundizar en nuestro entendimiento de los datos

# %% [markdown]
# ## Referencias
#
# 1. Kane, F. (2017). Hands-On Data Science and Python Machine Learning. Packt Publishing. (pp. 56-62).
